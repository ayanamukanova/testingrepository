# %%
import pandas as pd

# %%
df = pd.read_csv('ProjectData.csv')
df.head(30)
# Out:
#          date  mintemp  maxtemp  meantemp  rain  meanuv  maxuv  humidity  aqi
# 0    2022/1/1     16.4     19.3      17.6   0.0     1.0    2.0        76   86
# 1    2022/1/2     16.0     22.0      18.4   0.0     2.0    5.0        77   84
# 2    2022/1/3     17.0     20.5      18.3   0.0     2.0    5.0        79   81
# 3    2022/1/4     17.4     21.5      19.1   0.0     2.0    5.0        75   90
# 4    2022/1/5     18.3     23.6      20.4   0.1     2.0    5.0        75   68
# 5    2022/1/6     18.3     23.6      20.3   0.0     2.0    5.0        80   96
# 6    2022/1/7     17.2     21.1      18.6   0.0     2.0    5.0        79  105
# 7    2022/1/8     16.0     20.2      17.8   0.0     2.0    5.0        75   89
# 8    2022/1/9     16.7     20.1      18.0   0.0     1.0    5.0        79   90
# 9   2022/1/10     16.5     20.9      18.4   0.0     2.0    5.0        76   89
# 10  2022/1/11     13.7     18.8      15.8   1.2     2.0    5.0        70   74
# ...
